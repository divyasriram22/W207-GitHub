# %%
# IMPORTS 

# This tells matplotlib not to try opening a new window for each plot.
# %matplotlib inline

# Import a bunch of libraries.
import time
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from matplotlib.ticker import MultipleLocator
from sklearn.pipeline import Pipeline
from sklearn.datasets import fetch_mldata
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix
from sklearn.linear_model import LinearRegression
from sklearn.naive_bayes import BernoulliNB
from sklearn.naive_bayes import MultinomialNB
from sklearn.naive_bayes import GaussianNB
from sklearn.grid_search import GridSearchCV
from sklearn.metrics import classification_report
import scipy.stats


# Set the randomizer seed so results are the same each time.
np.random.seed(0)

# %%
train = pd.read_csv('../train_dev_data/train_data.csv')
train.head(200)
# Out:
#              id date_account_created  timestamp_first_active  \
# 0    g936neasyy           2013-05-12          20130512210934
# 1    duq2vabpp2           2013-03-02          20130302054534
# 2    xiymwcsklc           2011-05-17          20110517211429
# 3    8kkcksa0dw           2013-12-02          20131202180650
# 4    zk8qx61d9m           2013-11-07          20131107183734
# 5    m279vg69ql           2013-06-20          20130620041107
# 6    08j7fujqln           2012-11-23          20121123122454
# 7    zfn6qt4riu           2011-01-22          20110122230445
# 8    bzj8eo9zt1           2013-08-30          20130830170502
# 9    59firgevbj           2014-04-07          20140407225228
# 10   5iq23mqwtq           2013-07-15          20130715160316
# 11   abf77wvaj2           2014-02-26          20140226152810
# 12   fdjef8p2pd           2013-05-23          20130523031202
# 13   7jk5k3rjkc           2012-07-10          20120710215508
# 14   08clif8gvx           2014-06-27          20140627185435
# 15   j17rpehiay           2011-07-25          20110725195903
# 16   59kd3qkojk           2013-11-13          20131113071432
# 17   yy2ugwqm2e           2013-05-12          20130512011325
# 18   fd31rb6x0d           2014-06-13          20140613213030
# 19   t943nsvsj7           2013-10-02          20131002172642
# 20   zogn9tqm23           2014-05-29          20140529040332
# 21   nrl4pvb3s0           2013-06-02          20130602211632
# 22   jzpw1pfmp2           2012-05-28          20120528070745
# 23   qmwtniep22           2014-04-16          20140416054951
# 24   2ux5rx5nm2           2012-07-19          20120719185848
# 25   ky8rlq3jos           2013-11-25          20131125213715
# 26   ithdfhgkoi           2014-05-15          20140515212338
# 27   jtvb4la17l           2012-04-03          20120403045955
# 28   6u7tbp632t           2013-10-28          20131028003731
# 29   0p2fadwdgb           2013-08-18          20130818151043
# ..          ...                  ...                     ...
# 170  pu5zpzs1xc           2013-04-04          20130404190530
# 171  mtxkocqbta           2013-07-15          20130715194020
# 172  jr33xrxpyy           2014-03-25          20140325230941
# 173  bb7mzrxpw8           2012-08-23          20120823203833
# 174  y5nqa454ia           2012-03-29          20120329060854
# 175  3p8vmfoy9o           2013-09-26          20130926013851
# 176  uijf7171wm           2010-09-14          20100914200146
# 177  zsuhcjf18q           2013-08-04          20130804045431
# 178  ysvw979k6f           2014-06-17          20140617030612
# 179  p1myw0ukiz           2012-05-11          20120511125423
# 180  up6iurdble           2013-09-27          20130927171957
# 181  461m7iffdu           2012-06-04          20120604015309
# 182  91henc5i1n           2012-11-19          20121119042727
# 183  qyqeox0pzu           2012-08-20          20120820203208
# 184  6werzauxeh           2014-02-21          20140221020626
# 185  hk8ckt8n6u           2013-02-28          20130228165909
# 186  935cimevu6           2014-02-03          20140203065953
# 187  y8u3ayexn3           2014-02-13          20140213021229
# 188  8ypkpqkmka           2014-02-22          20140222031251
# 189  hfl2c281b6           2012-10-30          20121030171655
# 190  cy77wiqa0h           2013-05-12          20130512182245
# 191  cxzdq9plq5           2012-07-08          20120708233318
# 192  dc7tealhzw           2013-11-26          20131126145450
# 193  ob6ls30cxg           2012-02-13          20120213045658
# 194  f8y1x8sw6o           2014-01-24          20140124210850
# 195  i519ro1yxs           2010-04-21          20100421053010
# 196  ew38hy3ujq           2012-08-20          20120820225927
# 197  wsni0a1ahb           2012-12-25          20121225054227
# 198  hc7ljf00g0           2014-03-23          20140323214328
# 199  jkmxgpzvkh           2014-01-20          20140120223746
#
#     date_first_booking     gender    age signup_method  signup_flow language  \
# 0           2013-05-13  -unknown-    NaN         basic            0       en
# 1                  NaN     FEMALE   31.0      facebook            0       en
# 2                  NaN  -unknown-  105.0      facebook            2       en
# 3           2013-12-11  -unknown-   37.0         basic            0       en
# 4                  NaN     FEMALE   25.0         basic            0       en
# 5           2013-07-03     FEMALE   26.0      facebook            0       en
# 6                  NaN  -unknown-    NaN         basic           12       en
# 7           2011-02-18     FEMALE   35.0         basic            2       en
# 8           2013-08-30  -unknown-    NaN         basic            0       en
# 9                  NaN  -unknown-    NaN         basic            0       en
# 10          2013-07-21       MALE   34.0      facebook            0       en
# 11                 NaN       MALE   32.0      facebook            0       en
# 12                 NaN  -unknown-   19.0         basic            0       en
# 13                 NaN       MALE    NaN         basic            0       en
# 14          2014-08-13     FEMALE   23.0      facebook            0       en
# 15                 NaN  -unknown-    NaN         basic            2       en
# 16                 NaN     FEMALE   29.0      facebook            0       en
# 17                 NaN       MALE   44.0         basic           25       en
# 18                 NaN     FEMALE   29.0      facebook            0       en
# 19                 NaN  -unknown-    NaN         basic            0       en
# 20                 NaN  -unknown-    NaN         basic            0       en
# 21          2013-06-02     FEMALE   40.0         basic            0       en
# 22          2012-05-31  -unknown-   25.0         basic            3       en
# 23                 NaN       MALE   35.0      facebook            0       en
# 24          2012-07-27       MALE   31.0      facebook            0       en
# 25                 NaN       MALE   29.0      facebook           12       en
# 26                 NaN     FEMALE   47.0      facebook            0       en
# 27          2012-04-03     FEMALE   33.0         basic            0       en
# 28                 NaN       MALE   37.0         basic            0       en
# 29          2013-08-19  -unknown-    NaN         basic            0       zh
# ..                 ...        ...    ...           ...          ...      ...
# 170         2013-04-04  -unknown-    NaN         basic            0       en
# 171                NaN  -unknown-    NaN         basic            0       en
# 172         2014-03-26       MALE   51.0         basic            0       fr
# 173                NaN       MALE   33.0      facebook            0       en
# 174         2012-03-29  -unknown-    NaN         basic            3       en
# 175                NaN  -unknown-    NaN         basic            0       en
# 176                NaN       MALE   38.0         basic            2       en
# 177         2013-08-05     FEMALE   53.0         basic            0       en
# 178                NaN  -unknown-    NaN         basic           25       en
# 179         2012-12-12       MALE   46.0      facebook            0       en
# 180                NaN  -unknown-    NaN         basic            0       fr
# 181                NaN  -unknown-    NaN         basic            3       en
# 182                NaN  -unknown-    NaN         basic           12       en
# 183         2012-09-07       MALE    NaN         basic            0       sv
# 184                NaN       MALE   27.0      facebook           12       en
# 185                NaN  -unknown-   33.0         basic            0       en
# 186         2014-02-03     FEMALE   29.0      facebook            0       en
# 187                NaN  -unknown-    NaN         basic           25       en
# 188                NaN       MALE   41.0         basic            0       en
# 189                NaN     FEMALE   34.0         basic            0       en
# 190                NaN       MALE   29.0      facebook            0       en
# 191         2012-07-14     FEMALE   29.0         basic            3       en
# 192                NaN     FEMALE   22.0         basic            0       en
# 193         2012-02-21       MALE   32.0         basic            0       en
# 194                NaN  -unknown-    NaN         basic            0       en
# 195         2010-04-22     FEMALE   35.0      facebook            2       en
# 196                NaN     FEMALE    NaN         basic            0       en
# 197         2012-12-26     FEMALE   33.0         basic            0       en
# 198                NaN       MALE   37.0      facebook            0       en
# 199         2014-02-03     FEMALE   30.0      facebook            0       en
#
#     affiliate_channel affiliate_provider first_affiliate_tracked signup_app  \
# 0              direct             direct                  linked        Web
# 1              direct             direct               untracked        Web
# 2              direct             direct               untracked        Web
# 3           sem-brand             google                     omg        Web
# 4              direct             direct                  linked        Web
# 5              direct             direct               untracked        Web
# 6                 api              other                     NaN      Moweb
# 7       sem-non-brand               vast               untracked        Web
# 8              direct             direct               untracked        Web
# 9       sem-non-brand             google                     omg        Web
# 10             direct             direct                  linked        Web
# 11             direct             direct               untracked        Web
# 12             direct             direct               untracked        Web
# 13             direct             direct                  linked        Web
# 14             direct             direct                  linked        Web
# 15      sem-non-brand               bing               untracked        Web
# 16            content             google                     omg        Web
# 17             direct             direct               untracked        iOS
# 18          sem-brand             google                     omg        Web
# 19             direct             direct               untracked        Web
# 20          sem-brand             google                     omg        Web
# 21          sem-brand             google                     omg        Web
# 22             direct             direct               untracked        Web
# 23          sem-brand             google                     omg        Web
# 24             direct             direct               untracked        Web
# 25                api              other           tracked-other        iOS
# 26            content             google                     omg        Web
# 27              other              other               untracked        Web
# 28             direct             direct               untracked        Web
# 29             direct             direct                     omg        Web
# ..                ...                ...                     ...        ...
# 170            direct             direct               untracked        Web
# 171             other              other               untracked        Web
# 172               seo           facebook               untracked        Web
# 173            direct             direct               untracked        Web
# 174            direct             direct                     NaN        Web
# 175            direct             direct               untracked        Web
# 176            direct             direct           tracked-other        Web
# 177            direct             direct                  linked        Web
# 178            direct             direct               untracked        iOS
# 179               seo              other               untracked        Web
# 180     sem-non-brand             google                  linked        Web
# 181             other         craigslist           tracked-other        Web
# 182               api              other           tracked-other      Moweb
# 183            direct             direct               untracked        Web
# 184               api              other               untracked        iOS
# 185            direct             direct               untracked        Web
# 186            direct             direct                  linked        Web
# 187            direct             direct                  linked        iOS
# 188            direct             direct               untracked        Web
# 189            direct             direct               untracked        Web
# 190            direct             direct               untracked        Web
# 191            direct             direct               untracked        Web
# 192            direct             direct               untracked        Web
# 193            direct             direct               untracked        Web
# 194            direct             direct                  linked        Web
# 195             other         craigslist                  linked        Web
# 196            direct             direct                 product        Web
# 197     sem-non-brand             google                     omg        Web
# 198               seo             google                  linked        Web
# 199             other          padmapper           tracked-other        Web
#
#     first_device_type  first_browser country_destination
# 0         Mac Desktop         Chrome               other
# 1                iPad  Mobile Safari                 NDF
# 2         Mac Desktop        Firefox                 NDF
# 3                iPad  Mobile Safari                  US
# 4     Windows Desktop         Chrome                 NDF
# 5         Mac Desktop         Chrome                  FR
# 6       Other/Unknown      -unknown-                 NDF
# 7     Windows Desktop             IE               other
# 8     Windows Desktop         Chrome                  US
# 9     Windows Desktop             IE                 NDF
# 10    Windows Desktop         Chrome                  US
# 11        Mac Desktop         Chrome                 NDF
# 12        Mac Desktop        Firefox                 NDF
# 13    Windows Desktop        Firefox                 NDF
# 14             iPhone  Mobile Safari                  US
# 15        Mac Desktop         Safari                 NDF
# 16        Mac Desktop         Chrome                 NDF
# 17             iPhone      -unknown-                 NDF
# 18    Windows Desktop         Chrome                 NDF
# 19             iPhone  Mobile Safari                 NDF
# 20               iPad  Mobile Safari                 NDF
# 21    Windows Desktop        Firefox                  US
# 22        Mac Desktop         Chrome                  US
# 23        Mac Desktop         Chrome                 NDF
# 24        Mac Desktop         Safari                  US
# 25        Mac Desktop         Safari                 NDF
# 26    Windows Desktop        Firefox                 NDF
# 27    Windows Desktop             IE                  US
# 28    Windows Desktop         Chrome                 NDF
# 29               iPad  Mobile Safari               other
# ..                ...            ...                 ...
# 170   Windows Desktop         Chrome                  US
# 171   Windows Desktop        Firefox                 NDF
# 172   Windows Desktop        Firefox                  US
# 173   Windows Desktop         Chrome                 NDF
# 174     Other/Unknown      -unknown-                  US
# 175   Windows Desktop         Chrome                 NDF
# 176       Mac Desktop         Chrome                 NDF
# 177              iPad  Mobile Safari               other
# 178            iPhone      -unknown-                 NDF
# 179       Mac Desktop        Firefox                  US
# 180   Windows Desktop         Chrome                 NDF
# 181   Windows Desktop         Chrome                 NDF
# 182   Windows Desktop             IE                 NDF
# 183   Windows Desktop         Chrome                  US
# 184            iPhone      -unknown-                 NDF
# 185       Mac Desktop         Safari                 NDF
# 186   Windows Desktop         Chrome               other
# 187              iPad  Mobile Safari                 NDF
# 188              iPad  Mobile Safari                 NDF
# 189       Mac Desktop         Safari                 NDF
# 190       Mac Desktop         Chrome                 NDF
# 191       Mac Desktop         Chrome                  NL
# 192   Windows Desktop        Firefox                 NDF
# 193       Mac Desktop         Chrome                  US
# 194   Windows Desktop         Chrome                 NDF
# 195   Windows Desktop         Chrome                  US
# 196   Windows Desktop             IE                 NDF
# 197       Mac Desktop        Firefox                  US
# 198       Mac Desktop         Chrome                 NDF
# 199   Windows Desktop         Chrome                  GB
#
# [200 rows x 16 columns]

# %%
dev = pd.read_csv('../train_dev_data/dev_data.csv')
#dev.head()

# %%
#print(len(train))
#print(len(dev))

# %%
#creating labels sets from our train and dev data sets
train_labels = train.country_destination
dev_labels = dev.country_destination

# %%
languages = train.language.unique()
genders = train.gender.unique()
signup_methods = train.signup_method.unique()
affiliate_channels = train.affiliate_channel.unique()
signup_apps = train.signup_app.unique()
device_types = train.first_device_type.unique()
browsers = train.first_browser.unique()
destinations = train.country_destination.unique()

print"Possible language options: \n", languages, "\n"
print"Possible gender options: \n", genders, "\n"
print"Possible sign up methods options: \n", signup_methods, "\n"
print"Possible affiliate channels options: \n", affiliate_channels, "\n"
print"Possible sign up apps options: \n", signup_apps, "\n"
print"Possible device types options: \n", device_types, "\n"
print"Possible browsers options: \n", browsers, "\n"
print"Possible destinations options: \n", destinations, "\n"
# Out:
# Possible language options:
# ['en' 'zh' 'fr' 'sv' 'ja' 'it' 'es' 'ko' 'no' 'ru' 'da' 'de' 'pl' 'pt' 'el'
#  'nl' 'fi' 'tr' 'th' 'cs' 'hu' 'id' 'is' 'ca' 'hr']
#
# Possible gender options:
# ['-unknown-' 'FEMALE' 'MALE' 'OTHER']
#
# Possible sign up methods options:
# ['basic' 'facebook' 'google']
#
# Possible affiliate channels options:
# ['direct' 'sem-brand' 'api' 'sem-non-brand' 'content' 'other' 'seo'
#  'remarketing']
#
# Possible sign up apps options:
# ['Web' 'Moweb' 'iOS' 'Android']
#
# Possible device types options:
# ['Mac Desktop' 'iPad' 'Windows Desktop' 'Other/Unknown' 'iPhone'
#  'Android Phone' 'Desktop (Other)' 'Android Tablet' 'SmartPhone (Other)']
#
# Possible browsers options:
# ['Chrome' 'Mobile Safari' 'Firefox' '-unknown-' 'IE' 'Safari' 'Silk'
#  'Opera' 'AOL Explorer' 'Chrome Mobile' 'Iron' 'Android Browser'
#  'BlackBerry Browser' 'RockMelt' 'Sogou Explorer' 'Apple Mail' 'Chromium'
#  'SlimBrowser' 'IceWeasel' 'Maxthon' 'Yandex.Browser' 'IE Mobile'
#  'Pale Moon' 'SiteKiosk' 'Opera Mobile' 'wOSBrowser' 'Mobile Firefox'
#  'Arora' 'TenFourFox' 'Googlebot' 'SeaMonkey' 'CoolNovo' 'IceDragon'
#  'CometBird' 'Kindle Browser' 'Mozilla' 'NetNewsWire' 'OmniWeb'
#  'Comodo Dragon' 'Google Earth' 'Camino' 'Outlook 2007' 'Flock' 'Conkeror'
#  'Opera Mini' 'Palm Pre web browser' 'Avant Browser' 'TheWorld Browser'
#  'Crazy Browser' 'PS Vita browser' 'Stainless' 'Epic']
#
# Possible destinations options:
# ['other' 'NDF' 'US' 'FR' 'ES' 'CA' 'IT' 'GB' 'AU' 'NL' 'DE' 'PT']

# %%
# CORRELATION TRIAL 1:

columns_of_interest_corr = ['gender', 'country_destination']

corr_dummy = pd.get_dummies(train[['gender', 'country_destination']], columns=columns_of_interest_corr)
corr_dummy.corr()
# Out:
#                            gender_-unknown-  gender_FEMALE  gender_MALE  \
# gender_-unknown-                   1.000000      -0.583299    -0.527560
# gender_FEMALE                     -0.583299       1.000000    -0.378869
# gender_MALE                       -0.527560      -0.378869     1.000000
# gender_OTHER                      -0.033369      -0.023964    -0.021674
# country_destination_AU            -0.018201       0.010233     0.009970
# country_destination_CA            -0.016904       0.003879     0.014736
# country_destination_DE            -0.025850       0.005252     0.023701
# country_destination_ES            -0.025241       0.018230     0.009565
# country_destination_FR            -0.033181       0.032463     0.003414
# country_destination_GB            -0.026422       0.020016     0.009174
# country_destination_IT            -0.020332       0.023697    -0.001764
# country_destination_NDF            0.207554      -0.119394    -0.110440
# country_destination_NL            -0.017285       0.005131     0.013924
# country_destination_PT            -0.008586       0.004245     0.005070
# country_destination_US            -0.163270       0.096462     0.084469
# country_destination_other         -0.046899       0.008241     0.044423
#
#                            gender_OTHER  country_destination_AU  \
# gender_-unknown-              -0.033369               -0.018201
# gender_FEMALE                 -0.023964                0.010233
# gender_MALE                   -0.021674                0.009970
# gender_OTHER                   1.000000                0.001006
# country_destination_AU         0.001006                1.000000
# country_destination_CA         0.005739               -0.004130
# country_destination_DE         0.003421               -0.003584
# country_destination_ES         0.001810               -0.005177
# country_destination_FR         0.005542               -0.007829
# country_destination_GB         0.000277               -0.005260
# country_destination_IT         0.001924               -0.005853
# country_destination_NDF       -0.016431               -0.059391
# country_destination_NL         0.005001               -0.003006
# country_destination_PT         0.003331               -0.001599
# country_destination_US         0.009957               -0.032280
# country_destination_other      0.005323               -0.011161
#
#                            country_destination_CA  country_destination_DE  \
# gender_-unknown-                        -0.016904               -0.025850
# gender_FEMALE                            0.003879                0.005252
# gender_MALE                              0.014736                0.023701
# gender_OTHER                             0.005739                0.003421
# country_destination_AU                  -0.004130               -0.003584
# country_destination_CA                   1.000000               -0.005869
# country_destination_DE                  -0.005869                1.000000
# country_destination_ES                  -0.008479               -0.007358
# country_destination_FR                  -0.012822               -0.011127
# country_destination_GB                  -0.008614               -0.007475
# country_destination_IT                  -0.009586               -0.008319
# country_destination_NDF                 -0.097267               -0.084409
# country_destination_NL                  -0.004923               -0.004273
# country_destination_PT                  -0.002620               -0.002273
# country_destination_US                  -0.052867               -0.045878
# country_destination_other               -0.018278               -0.015862
#
#                            country_destination_ES  country_destination_FR  \
# gender_-unknown-                        -0.025241               -0.033181
# gender_FEMALE                            0.018230                0.032463
# gender_MALE                              0.009565                0.003414
# gender_OTHER                             0.001810                0.005542
# country_destination_AU                  -0.005177               -0.007829
# country_destination_CA                  -0.008479               -0.012822
# country_destination_DE                  -0.007358               -0.011127
# country_destination_ES                   1.000000               -0.016074
# country_destination_FR                  -0.016074                1.000000
# country_destination_GB                  -0.010799               -0.016330
# country_destination_IT                  -0.012017               -0.018172
# country_destination_NDF                 -0.121936               -0.184396
# country_destination_NL                  -0.006172               -0.009334
# country_destination_PT                  -0.003284               -0.004966
# country_destination_US                  -0.066275               -0.100223
# country_destination_other               -0.022914               -0.034652
#
#                            country_destination_GB  country_destination_IT  \
# gender_-unknown-                        -0.026422               -0.020332
# gender_FEMALE                            0.020016                0.023697
# gender_MALE                              0.009174               -0.001764
# gender_OTHER                             0.000277                0.001924
# country_destination_AU                  -0.005260               -0.005853
# country_destination_CA                  -0.008614               -0.009586
# country_destination_DE                  -0.007475               -0.008319
# country_destination_ES                  -0.010799               -0.012017
# country_destination_FR                  -0.016330               -0.018172
# country_destination_GB                   1.000000               -0.012209
# country_destination_IT                  -0.012209                1.000000
# country_destination_NDF                 -0.123880               -0.137858
# country_destination_NL                  -0.006270               -0.006978
# country_destination_PT                  -0.003336               -0.003713
# country_destination_US                  -0.067331               -0.074929
# country_destination_other               -0.023280               -0.025906
#
#                            country_destination_NDF  country_destination_NL  \
# gender_-unknown-                          0.207554               -0.017285
# gender_FEMALE                            -0.119394                0.005131
# gender_MALE                              -0.110440                0.013924
# gender_OTHER                             -0.016431                0.005001
# country_destination_AU                   -0.059391               -0.003006
# country_destination_CA                   -0.097267               -0.004923
# country_destination_DE                   -0.084409               -0.004273
# country_destination_ES                   -0.121936               -0.006172
# country_destination_FR                   -0.184396               -0.009334
# country_destination_GB                   -0.123880               -0.006270
# country_destination_IT                   -0.137858               -0.006978
# country_destination_NDF                   1.000000               -0.070806
# country_destination_NL                   -0.070806                1.000000
# country_destination_PT                   -0.037672               -0.001907
# country_destination_US                   -0.760300               -0.038484
# country_destination_other                -0.262871               -0.013306
#
#                            country_destination_PT  country_destination_US  \
# gender_-unknown-                        -0.008586               -0.163270
# gender_FEMALE                            0.004245                0.096462
# gender_MALE                              0.005070                0.084469
# gender_OTHER                             0.003331                0.009957
# country_destination_AU                  -0.001599               -0.032280
# country_destination_CA                  -0.002620               -0.052867
# country_destination_DE                  -0.002273               -0.045878
# country_destination_ES                  -0.003284               -0.066275
# country_destination_FR                  -0.004966               -0.100223
# country_destination_GB                  -0.003336               -0.067331
# country_destination_IT                  -0.003713               -0.074929
# country_destination_NDF                 -0.037672               -0.760300
# country_destination_NL                  -0.001907               -0.038484
# country_destination_PT                   1.000000               -0.020476
# country_destination_US                  -0.020476                1.000000
# country_destination_other               -0.007079               -0.142875
#
#                            country_destination_other
# gender_-unknown-                           -0.046899
# gender_FEMALE                               0.008241
# gender_MALE                                 0.044423
# gender_OTHER                                0.005323
# country_destination_AU                     -0.011161
# country_destination_CA                     -0.018278
# country_destination_DE                     -0.015862
# country_destination_ES                     -0.022914
# country_destination_FR                     -0.034652
# country_destination_GB                     -0.023280
# country_destination_IT                     -0.025906
# country_destination_NDF                    -0.262871
# country_destination_NL                     -0.013306
# country_destination_PT                     -0.007079
# country_destination_US                     -0.142875
# country_destination_other                   1.000000

# %%
#TRIAL 1: language, gender, sign up method (knn best accuracy: 0.59)


columns_of_interest = ['language', 'gender', 'signup_method']
#columns_of_interest = ['language', 'gender', 'signup_app']

#creating new dataframe from train with integer values for categorical variables
#only including columns / variables of interest
train_dummy = pd.get_dummies(train[['language', 'gender', 'signup_method']], columns=columns_of_interest)
dev_dummy = pd.get_dummies(dev[['language', 'gender', 'signup_method']], columns=columns_of_interest)

# %%
# TRIAL 2: gender, sign up method (knn best accuracy: 0.58)
    
columns_of_interest = ['gender', 'signup_method']
#columns_of_interest = ['language', 'gender', 'signup_app']

#creating new dataframe from train with integer values for categorical variables
#only including columns / variables of interest
train_dummy = pd.get_dummies(train[['gender', 'signup_method']], columns=columns_of_interest)
dev_dummy = pd.get_dummies(dev[['gender', 'signup_method']], columns=columns_of_interest)

# %% [markdown]
# EXPLORATORY ANALYSIS

# %%
# Note that training data has two extra languages in it - ca & hr
# We need to add dummy columns for ca & hr to the dev data

# List of columns in transformed training data & dev data
train_dummy_list = list(train_dummy.columns.values)
dev_dummy_list = list(dev_dummy.columns.values)

# difference between the sets
np.setdiff1d(train_dummy_list, dev_dummy_list)
# Out:
# array([],
#       dtype='|S22')

# %%
list(train_dummy)
# Out:
# ['language_ca',
#  'language_cs',
#  'language_da',
#  'language_de',
#  'language_el',
#  'language_en',
#  'language_es',
#  'language_fi',
#  'language_fr',
#  'language_hr',
#  'language_hu',
#  'language_id',
#  'language_is',
#  'language_it',
#  'language_ja',
#  'language_ko',
#  'language_nl',
#  'language_no',
#  'language_pl',
#  'language_pt',
#  'language_ru',
#  'language_sv',
#  'language_th',
#  'language_tr',
#  'language_zh',
#  'gender_-unknown-',
#  'gender_FEMALE',
#  'gender_MALE',
#  'gender_OTHER',
#  'signup_method_basic',
#  'signup_method_facebook',
#  'signup_method_google']

# %%
list(dev_dummy)
# Out:
# ['language_ca',
#  'language_cs',
#  'language_da',
#  'language_de',
#  'language_el',
#  'language_en',
#  'language_es',
#  'language_fi',
#  'language_fr',
#  'language_hr',
#  'language_hu',
#  'language_id',
#  'language_is',
#  'language_it',
#  'language_ja',
#  'language_ko',
#  'language_nl',
#  'language_no',
#  'language_pl',
#  'language_pt',
#  'language_ru',
#  'language_sv',
#  'language_th',
#  'language_tr',
#  'language_zh',
#  'gender_-unknown-',
#  'gender_FEMALE',
#  'gender_MALE',
#  'gender_OTHER',
#  'signup_method_basic',
#  'signup_method_facebook',
#  'signup_method_google']

# %%
# Create arrays based on the variables we want to use
train_array = np.array(train_dummy)
train_label_array = np.array(train_labels)

dev_array = np.array(dev_dummy)
dev_label_array = np.array(dev_labels)

# %%
def knn_model_test(k_vals, train_data, train_labels, dev_data, dev_labels):

### STUDENT START ###

    # We want to evaluate a variety of values for k, so we need
    # to enclose our work in a loop.
    for elem in k_vals:
        
        # Create a classifier object, fit our training data &
        # initialize a variable to hold the predictions
        knn = KNeighborsClassifier(n_neighbors=elem)
        knn.fit(train_data, train_labels)
        preds = knn.predict(dev_data)
        
        # We evaluate the accuracy for each value of k by comparing
        # the predictions and the labels, then updating values for
        # correct and total
        correct, total = 0, 0
        for pred, label in zip(preds, dev_labels):
            if pred == label: 
                correct += 1
            total += 1
        print 'For k=%s, total: %3d  correct: %3d  accuracy: %3.2f' %(elem, total, correct, 1.0*correct/total)

k_vals = [7, 10, 15, 20, 50]
knn_model_test(k_vals, train_array[:2000], train_label_array[:2000], dev_array[:2000], dev_label_array[:2000])
# Out:
# For k=7, total: 2000  correct: 1183  accuracy: 0.59
# For k=10, total: 2000  correct: 1158  accuracy: 0.58
# For k=15, total: 2000  correct: 1161  accuracy: 0.58
# For k=20, total: 2000  correct: 1160  accuracy: 0.58
# For k=50, total: 2000  correct: 1161  accuracy: 0.58
