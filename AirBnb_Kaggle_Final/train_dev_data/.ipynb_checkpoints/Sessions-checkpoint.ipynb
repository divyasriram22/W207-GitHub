# %%
# This tells matplotlib not to try opening a new window for each plot.
# %matplotlib inline

# General libraries.
import re
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# SK-learn library for preprocessing
from sklearn import preprocessing

# SK-learn libraries for learning.
from sklearn.pipeline import Pipeline
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import BernoulliNB
from sklearn.naive_bayes import MultinomialNB
from sklearn.grid_search import GridSearchCV

# SK-learn libraries for evaluation.
from sklearn.metrics import confusion_matrix
from sklearn import metrics
from sklearn.metrics import classification_report

# Set the randomizer seed so results are the same each time.
np.random.seed(0)

# %%
# Read in csv and create arrays
users_train_raw = pd.read_csv('../zip_files/train_users_2.csv.zip')
sessions_raw = pd.read_csv('../zip_files/sessions.csv.zip')
demographics = pd.read_csv('../zip_files/age_gender_bkts.csv.zip')
countries = pd.read_csv('../zip_files/countries.csv.zip')
test = pd.read_csv('../zip_files/test_users.csv.zip')
sessions = pd.read_csv('../zip_files/sessions.csv.zip')

# %%
users_train_raw.rename(columns={'id': 'user_id'}, inplace=True)
test.rename(columns={'id': 'user_id'}, inplace=True)

# %%
users_train_raw
# Out:
#            user_id date_account_created  timestamp_first_active  \
# 0       gxn3p5htnn           2010-06-28          20090319043255
# 1       820tgsjxq7           2011-05-25          20090523174809
# 2       4ft3gnwmtx           2010-09-28          20090609231247
# 3       bjjt8pjhuk           2011-12-05          20091031060129
# 4       87mebub9p4           2010-09-14          20091208061105
# 5       osr2jwljor           2010-01-01          20100101215619
# 6       lsw9q7uk0j           2010-01-02          20100102012558
# 7       0d01nltbrs           2010-01-03          20100103191905
# 8       a1vcnhxeij           2010-01-04          20100104004211
# 9       6uh8zyj2gn           2010-01-04          20100104023758
# 10      yuuqmid2rp           2010-01-04          20100104194251
# 11      om1ss59ys8           2010-01-05          20100105051812
# 12      k6np330cm1           2010-01-05          20100105060859
# 13      dy3rgx56cu           2010-01-05          20100105083259
# 14      ju3h98ch3w           2010-01-07          20100107055820
# 15      v4d5rl22px           2010-01-07          20100107204555
# 16      2dwbwkx056           2010-01-07          20100107215125
# 17      frhre329au           2010-01-07          20100107224625
# 18      cxlg85pg1r           2010-01-08          20100108015641
# 19      gdka1q5ktd           2010-01-10          20100110010817
# 20      qdubonn3uk           2010-01-10          20100110152120
# 21      qsibmuz9sx           2010-01-10          20100110220941
# 22      80f7dwscrn           2010-01-11          20100111031438
# 23      jha93x042q           2010-01-11          20100111224015
# 24      7i49vnuav6           2010-01-11          20100111230808
# 25      al8bcetz0g           2010-01-12          20100112131444
# 26      bjg0m5otl3           2010-01-12          20100112155420
# 27      hfrl5gle36           2010-01-12          20100112205949
# 28      tp6x3md0n4           2010-01-13          20100113044650
# 29      hql77nu2lk           2010-01-13          20100113064333
# ...            ...                  ...                     ...
# 213421  c98s3h7kgj           2014-06-30          20140630231137
# 213422  ytmpiwb8hj           2014-06-30          20140630231246
# 213423  3dx1jk6yk2           2014-06-30          20140630231548
# 213424  hcfj07iowv           2014-06-30          20140630231859
# 213425  l1f71f9vsj           2014-06-30          20140630232119
# 213426  15bj4ahmhf           2014-06-30          20140630232331
# 213427  qwpybxfjdl           2014-06-30          20140630232539
# 213428  k4t61wuvyq           2014-06-30          20140630232634
# 213429  mhh7b52z44           2014-06-30          20140630232712
# 213430  79wk7k2k5t           2014-06-30          20140630233132
# 213431  ftwmocvwlq           2014-06-30          20140630233203
# 213432  rg7ayg1tob           2014-06-30          20140630233224
# 213433  2f24umzkuv           2014-06-30          20140630233427
# 213434  or77n2ojuj           2014-06-30          20140630233640
# 213435  0a5bnb9bs4           2014-06-30          20140630233851
# 213436  6fzrn49sfn           2014-06-30          20140630234113
# 213437  r0jq0devgy           2014-06-30          20140630234243
# 213438  v5lq9bj8gv           2014-06-30          20140630234429
# 213439  msucfwmlzc           2014-06-30          20140630234729
# 213440  04y8115avm           2014-06-30          20140630234933
# 213441  omlc9iku7t           2014-06-30          20140630235151
# 213442  rf0ay567js           2014-06-30          20140630235309
# 213443  0k26r3mir0           2014-06-30          20140630235340
# 213444  40o1ivh6cb           2014-06-30          20140630235352
# 213445  qbxza0xojf           2014-06-30          20140630235547
# 213446  zxodksqpep           2014-06-30          20140630235636
# 213447  mhewnxesx9           2014-06-30          20140630235719
# 213448  6o3arsjbb4           2014-06-30          20140630235754
# 213449  jh95kwisub           2014-06-30          20140630235822
# 213450  nw9fwlyb5f           2014-06-30          20140630235824
#
#        date_first_booking     gender   age signup_method  signup_flow  \
# 0                     NaT  -unknown-   NaN      facebook            0
# 1                     NaT       MALE  38.0      facebook            0
# 2              2010-08-02     FEMALE  56.0         basic            3
# 3              2012-09-08     FEMALE  42.0      facebook            0
# 4              2010-02-18  -unknown-  41.0         basic            0
# 5              2010-01-02  -unknown-   NaN         basic            0
# 6              2010-01-05     FEMALE  46.0         basic            0
# 7              2010-01-13     FEMALE  47.0         basic            0
# 8              2010-07-29     FEMALE  50.0         basic            0
# 9              2010-01-04  -unknown-  46.0         basic            0
# 10             2010-01-06     FEMALE  36.0         basic            0
# 11                    NaT     FEMALE  47.0         basic            0
# 12             2010-01-18  -unknown-   NaN         basic            0
# 13                    NaT     FEMALE  37.0         basic            0
# 14                    NaT     FEMALE  36.0         basic            0
# 15             2010-01-08     FEMALE  33.0         basic            0
# 16                    NaT  -unknown-   NaN         basic            0
# 17             2010-01-09  -unknown-  31.0         basic            0
# 18                    NaT  -unknown-   NaN         basic            0
# 19             2010-01-10     FEMALE  29.0         basic            0
# 20             2010-01-18  -unknown-   NaN         basic            0
# 21             2010-01-11       MALE  30.0         basic            0
# 22             2010-01-11  -unknown-  40.0         basic            0
# 23                    NaT  -unknown-   NaN         basic            0
# 24                    NaT     FEMALE  40.0         basic            0
# 25             2010-01-15     FEMALE  26.0         basic            0
# 26                    NaT  -unknown-   NaN         basic            0
# 27             2010-01-22     FEMALE  32.0         basic            0
# 28             2010-01-13  -unknown-  35.0         basic            0
# 29             2010-01-19  -unknown-  37.0         basic            0
# ...                   ...        ...   ...           ...          ...
# 213421                NaT  -unknown-   NaN         basic            0
# 213422                NaT  -unknown-   NaN         basic            0
# 213423                NaT     FEMALE  20.0      facebook           25
# 213424                NaT     FEMALE  32.0      facebook            0
# 213425                NaT     FEMALE  30.0      facebook            0
# 213426                NaT  -unknown-   NaN         basic            0
# 213427                NaT  -unknown-   NaN         basic            0
# 213428                NaT  -unknown-   NaN         basic           23
# 213429                NaT  -unknown-   NaN         basic           25
# 213430                NaT  -unknown-  19.0         basic            0
# 213431                NaT  -unknown-   NaN         basic            0
# 213432                NaT       MALE  31.0      facebook            0
# 213433                NaT  -unknown-   NaN         basic            0
# 213434                NaT  -unknown-   NaN         basic            0
# 213435                NaT  -unknown-   NaN         basic            0
# 213436                NaT  -unknown-   NaN         basic           25
# 213437                NaT  -unknown-   NaN         basic           23
# 213438                NaT  -unknown-   NaN         basic           25
# 213439         2015-03-16       MALE  43.0         basic            0
# 213440                NaT     FEMALE  24.0         basic           25
# 213441         2014-08-13     FEMALE  34.0         basic            0
# 213442                NaT  -unknown-   NaN         basic            0
# 213443         2014-07-13     FEMALE  36.0         basic            0
# 213444                NaT  -unknown-   NaN         basic            0
# 213445         2014-07-02     FEMALE  23.0         basic            0
# 213446                NaT       MALE  32.0         basic            0
# 213447                NaT  -unknown-   NaN         basic            0
# 213448                NaT  -unknown-  32.0         basic            0
# 213449                NaT  -unknown-   NaN         basic           25
# 213450                NaT  -unknown-   NaN         basic           25
#
#        language affiliate_channel affiliate_provider first_affiliate_tracked  \
# 0            en            direct             direct               untracked
# 1            en               seo             google               untracked
# 2            en            direct             direct               untracked
# 3            en            direct             direct               untracked
# 4            en            direct             direct               untracked
# 5            en             other              other                     omg
# 6            en             other         craigslist               untracked
# 7            en            direct             direct                     omg
# 8            en             other         craigslist               untracked
# 9            en             other         craigslist                     omg
# 10           en             other         craigslist               untracked
# 11           en             other         craigslist               untracked
# 12           en            direct             direct                     NaN
# 13           en             other         craigslist                  linked
# 14           en             other         craigslist               untracked
# 15           en            direct             direct               untracked
# 16           en             other         craigslist                     NaN
# 17           en             other         craigslist                     NaN
# 18           en               seo           facebook                     NaN
# 19           en            direct             direct               untracked
# 20           en            direct             direct                     NaN
# 21           en            direct             direct                  linked
# 22           en               seo             google               untracked
# 23           en             other         craigslist               untracked
# 24           en               seo             google               untracked
# 25           en             other         craigslist               untracked
# 26           en             other              other               untracked
# 27           en             other         craigslist               untracked
# 28           en            direct             direct                     NaN
# 29           en            direct             direct               untracked
# ...         ...               ...                ...                     ...
# 213421       en            direct             direct                  linked
# 213422       en            direct             direct               untracked
# 213423       en            direct             direct               untracked
# 213424       en            direct             direct                  linked
# 213425       en            direct             direct                  linked
# 213426       en            direct             direct               untracked
# 213427       en            direct             direct                  linked
# 213428       en            direct             direct               untracked
# 213429       en            direct             direct               untracked
# 213430       en            direct             direct                  linked
# 213431       en            direct             direct               untracked
# 213432       en            direct             direct           tracked-other
# 213433       en         sem-brand             google               untracked
# 213434       en               seo           facebook                 product
# 213435       en               seo             google               untracked
# 213436       en            direct             direct               untracked
# 213437       en            direct             direct               untracked
# 213438       en            direct             direct               untracked
# 213439       en            direct             direct               untracked
# 213440       en            direct             direct               untracked
# 213441       en            direct             direct                  linked
# 213442       en         sem-brand             google                     omg
# 213443       en         sem-brand             google                  linked
# 213444       en            direct             direct                  linked
# 213445       en         sem-brand             google                     omg
# 213446       en         sem-brand             google                     omg
# 213447       en            direct             direct                  linked
# 213448       en            direct             direct               untracked
# 213449       en             other              other           tracked-other
# 213450       en            direct             direct               untracked
#
#        signup_app first_device_type  first_browser country_destination  \
# 0             Web       Mac Desktop         Chrome                 NDF
# 1             Web       Mac Desktop         Chrome                 NDF
# 2             Web   Windows Desktop             IE                  US
# 3             Web       Mac Desktop        Firefox               other
# 4             Web       Mac Desktop         Chrome                  US
# 5             Web       Mac Desktop         Chrome                  US
# 6             Web       Mac Desktop         Safari                  US
# 7             Web       Mac Desktop         Safari                  US
# 8             Web       Mac Desktop         Safari                  US
# 9             Web       Mac Desktop        Firefox                  US
# 10            Web       Mac Desktop        Firefox                  US
# 11            Web            iPhone      -unknown-                 NDF
# 12            Web     Other/Unknown      -unknown-                  FR
# 13            Web       Mac Desktop        Firefox                 NDF
# 14            Web            iPhone  Mobile Safari                 NDF
# 15            Web   Windows Desktop         Chrome                  CA
# 16            Web     Other/Unknown      -unknown-                 NDF
# 17            Web     Other/Unknown      -unknown-                  US
# 18            Web     Other/Unknown      -unknown-                 NDF
# 19            Web       Mac Desktop         Chrome                  FR
# 20            Web     Other/Unknown      -unknown-                  US
# 21            Web       Mac Desktop         Chrome                  US
# 22            Web            iPhone      -unknown-                  US
# 23            Web       Mac Desktop         Safari                 NDF
# 24            Web       Mac Desktop        Firefox                 NDF
# 25            Web       Mac Desktop         Chrome                  FR
# 26            Web     Other/Unknown      -unknown-                 NDF
# 27            Web   Desktop (Other)         Chrome                  US
# 28            Web     Other/Unknown      -unknown-                  FR
# 29            Web    Android Tablet      -unknown-                  US
# ...           ...               ...            ...                 ...
# 213421        Web       Mac Desktop        Firefox                 NDF
# 213422        Web   Windows Desktop             IE                 NDF
# 213423        iOS            iPhone      -unknown-                 NDF
# 213424        Web   Windows Desktop         Chrome                 NDF
# 213425        Web   Windows Desktop         Chrome                 NDF
# 213426      Moweb     Android Phone  Chrome Mobile                 NDF
# 213427        Web   Desktop (Other)         Chrome                 NDF
# 213428    Android     Android Phone      -unknown-                 NDF
# 213429        iOS            iPhone      -unknown-                 NDF
# 213430        Web       Mac Desktop         Chrome                 NDF
# 213431        Web   Windows Desktop        Firefox                 NDF
# 213432        Web       Mac Desktop         Safari                 NDF
# 213433        Web              iPad  Mobile Safari                 NDF
# 213434        Web       Mac Desktop         Chrome                 NDF
# 213435        Web   Windows Desktop         Chrome                 NDF
# 213436        iOS            iPhone      -unknown-                 NDF
# 213437    Android    Android Tablet      -unknown-                 NDF
# 213438        iOS            iPhone      -unknown-                 NDF
# 213439        Web   Windows Desktop        Firefox                  US
# 213440        iOS            iPhone  Mobile Safari                 NDF
# 213441        Web       Mac Desktop         Chrome                  ES
# 213442        Web       Mac Desktop         Chrome                 NDF
# 213443        Web       Mac Desktop         Safari                  US
# 213444        Web   Windows Desktop         Chrome                 NDF
# 213445        Web   Windows Desktop             IE                  US
# 213446        Web       Mac Desktop         Safari                 NDF
# 213447        Web   Windows Desktop         Chrome                 NDF
# 213448        Web       Mac Desktop        Firefox                 NDF
# 213449        iOS            iPhone  Mobile Safari                 NDF
# 213450        iOS            iPhone      -unknown-                 NDF
#
#         signup_delta
# 0                NaT
# 1                NaT
# 2            57 days
# 3          -278 days
# 4           208 days
# 5            -1 days
# 6            -3 days
# 7           -10 days
# 8          -206 days
# 9             0 days
# 10           -2 days
# 11               NaT
# 12          -13 days
# 13               NaT
# 14               NaT
# 15           -1 days
# 16               NaT
# 17           -2 days
# 18               NaT
# 19            0 days
# 20           -8 days
# 21           -1 days
# 22            0 days
# 23               NaT
# 24               NaT
# 25           -3 days
# 26               NaT
# 27          -10 days
# 28            0 days
# 29           -6 days
# ...              ...
# 213421           NaT
# 213422           NaT
# 213423           NaT
# 213424           NaT
# 213425           NaT
# 213426           NaT
# 213427           NaT
# 213428           NaT
# 213429           NaT
# 213430           NaT
# 213431           NaT
# 213432           NaT
# 213433           NaT
# 213434           NaT
# 213435           NaT
# 213436           NaT
# 213437           NaT
# 213438           NaT
# 213439     -259 days
# 213440           NaT
# 213441      -44 days
# 213442           NaT
# 213443      -13 days
# 213444           NaT
# 213445       -2 days
# 213446           NaT
# 213447           NaT
# 213448           NaT
# 213449           NaT
# 213450           NaT
#
# [213451 rows x 17 columns]

# %%
new_train_raw
# Out:
#            user_id date_account_created  timestamp_first_active  \
# 0       gxn3p5htnn           2010-06-28          20090319043255
# 1       820tgsjxq7           2011-05-25          20090523174809
# 2       4ft3gnwmtx           2010-09-28          20090609231247
# 3       bjjt8pjhuk           2011-12-05          20091031060129
# 4       87mebub9p4           2010-09-14          20091208061105
# 5       osr2jwljor           2010-01-01          20100101215619
# 6       lsw9q7uk0j           2010-01-02          20100102012558
# 7       0d01nltbrs           2010-01-03          20100103191905
# 8       a1vcnhxeij           2010-01-04          20100104004211
# 9       6uh8zyj2gn           2010-01-04          20100104023758
# 10      yuuqmid2rp           2010-01-04          20100104194251
# 11      om1ss59ys8           2010-01-05          20100105051812
# 12      k6np330cm1           2010-01-05          20100105060859
# 13      dy3rgx56cu           2010-01-05          20100105083259
# 14      ju3h98ch3w           2010-01-07          20100107055820
# 15      v4d5rl22px           2010-01-07          20100107204555
# 16      2dwbwkx056           2010-01-07          20100107215125
# 17      frhre329au           2010-01-07          20100107224625
# 18      cxlg85pg1r           2010-01-08          20100108015641
# 19      gdka1q5ktd           2010-01-10          20100110010817
# 20      qdubonn3uk           2010-01-10          20100110152120
# 21      qsibmuz9sx           2010-01-10          20100110220941
# 22      80f7dwscrn           2010-01-11          20100111031438
# 23      jha93x042q           2010-01-11          20100111224015
# 24      7i49vnuav6           2010-01-11          20100111230808
# 25      al8bcetz0g           2010-01-12          20100112131444
# 26      bjg0m5otl3           2010-01-12          20100112155420
# 27      hfrl5gle36           2010-01-12          20100112205949
# 28      tp6x3md0n4           2010-01-13          20100113044650
# 29      hql77nu2lk           2010-01-13          20100113064333
# ...            ...                  ...                     ...
# 213421  c98s3h7kgj           2014-06-30          20140630231137
# 213422  ytmpiwb8hj           2014-06-30          20140630231246
# 213423  3dx1jk6yk2           2014-06-30          20140630231548
# 213424  hcfj07iowv           2014-06-30          20140630231859
# 213425  l1f71f9vsj           2014-06-30          20140630232119
# 213426  15bj4ahmhf           2014-06-30          20140630232331
# 213427  qwpybxfjdl           2014-06-30          20140630232539
# 213428  k4t61wuvyq           2014-06-30          20140630232634
# 213429  mhh7b52z44           2014-06-30          20140630232712
# 213430  79wk7k2k5t           2014-06-30          20140630233132
# 213431  ftwmocvwlq           2014-06-30          20140630233203
# 213432  rg7ayg1tob           2014-06-30          20140630233224
# 213433  2f24umzkuv           2014-06-30          20140630233427
# 213434  or77n2ojuj           2014-06-30          20140630233640
# 213435  0a5bnb9bs4           2014-06-30          20140630233851
# 213436  6fzrn49sfn           2014-06-30          20140630234113
# 213437  r0jq0devgy           2014-06-30          20140630234243
# 213438  v5lq9bj8gv           2014-06-30          20140630234429
# 213439  msucfwmlzc           2014-06-30          20140630234729
# 213440  04y8115avm           2014-06-30          20140630234933
# 213441  omlc9iku7t           2014-06-30          20140630235151
# 213442  rf0ay567js           2014-06-30          20140630235309
# 213443  0k26r3mir0           2014-06-30          20140630235340
# 213444  40o1ivh6cb           2014-06-30          20140630235352
# 213445  qbxza0xojf           2014-06-30          20140630235547
# 213446  zxodksqpep           2014-06-30          20140630235636
# 213447  mhewnxesx9           2014-06-30          20140630235719
# 213448  6o3arsjbb4           2014-06-30          20140630235754
# 213449  jh95kwisub           2014-06-30          20140630235822
# 213450  nw9fwlyb5f           2014-06-30          20140630235824
#
#        date_first_booking     gender   age signup_method  signup_flow  \
# 0                     NaT  -unknown-   NaN      facebook            0
# 1                     NaT       MALE  38.0      facebook            0
# 2              2010-08-02     FEMALE  56.0         basic            3
# 3              2012-09-08     FEMALE  42.0      facebook            0
# 4              2010-02-18  -unknown-  41.0         basic            0
# 5              2010-01-02  -unknown-   NaN         basic            0
# 6              2010-01-05     FEMALE  46.0         basic            0
# 7              2010-01-13     FEMALE  47.0         basic            0
# 8              2010-07-29     FEMALE  50.0         basic            0
# 9              2010-01-04  -unknown-  46.0         basic            0
# 10             2010-01-06     FEMALE  36.0         basic            0
# 11                    NaT     FEMALE  47.0         basic            0
# 12             2010-01-18  -unknown-   NaN         basic            0
# 13                    NaT     FEMALE  37.0         basic            0
# 14                    NaT     FEMALE  36.0         basic            0
# 15             2010-01-08     FEMALE  33.0         basic            0
# 16                    NaT  -unknown-   NaN         basic            0
# 17             2010-01-09  -unknown-  31.0         basic            0
# 18                    NaT  -unknown-   NaN         basic            0
# 19             2010-01-10     FEMALE  29.0         basic            0
# 20             2010-01-18  -unknown-   NaN         basic            0
# 21             2010-01-11       MALE  30.0         basic            0
# 22             2010-01-11  -unknown-  40.0         basic            0
# 23                    NaT  -unknown-   NaN         basic            0
# 24                    NaT     FEMALE  40.0         basic            0
# 25             2010-01-15     FEMALE  26.0         basic            0
# 26                    NaT  -unknown-   NaN         basic            0
# 27             2010-01-22     FEMALE  32.0         basic            0
# 28             2010-01-13  -unknown-  35.0         basic            0
# 29             2010-01-19  -unknown-  37.0         basic            0
# ...                   ...        ...   ...           ...          ...
# 213421                NaT  -unknown-   NaN         basic            0
# 213422                NaT  -unknown-   NaN         basic            0
# 213423                NaT     FEMALE  20.0      facebook           25
# 213424                NaT     FEMALE  32.0      facebook            0
# 213425                NaT     FEMALE  30.0      facebook            0
# 213426                NaT  -unknown-   NaN         basic            0
# 213427                NaT  -unknown-   NaN         basic            0
# 213428                NaT  -unknown-   NaN         basic           23
# 213429                NaT  -unknown-   NaN         basic           25
# 213430                NaT  -unknown-  19.0         basic            0
# 213431                NaT  -unknown-   NaN         basic            0
# 213432                NaT       MALE  31.0      facebook            0
# 213433                NaT  -unknown-   NaN         basic            0
# 213434                NaT  -unknown-   NaN         basic            0
# 213435                NaT  -unknown-   NaN         basic            0
# 213436                NaT  -unknown-   NaN         basic           25
# 213437                NaT  -unknown-   NaN         basic           23
# 213438                NaT  -unknown-   NaN         basic           25
# 213439         2015-03-16       MALE  43.0         basic            0
# 213440                NaT     FEMALE  24.0         basic           25
# 213441         2014-08-13     FEMALE  34.0         basic            0
# 213442                NaT  -unknown-   NaN         basic            0
# 213443         2014-07-13     FEMALE  36.0         basic            0
# 213444                NaT  -unknown-   NaN         basic            0
# 213445         2014-07-02     FEMALE  23.0         basic            0
# 213446                NaT       MALE  32.0         basic            0
# 213447                NaT  -unknown-   NaN         basic            0
# 213448                NaT  -unknown-  32.0         basic            0
# 213449                NaT  -unknown-   NaN         basic           25
# 213450                NaT  -unknown-   NaN         basic           25
#
#        language affiliate_channel     ...     first_device_type  \
# 0            en            direct     ...           Mac Desktop
# 1            en               seo     ...           Mac Desktop
# 2            en            direct     ...       Windows Desktop
# 3            en            direct     ...           Mac Desktop
# 4            en            direct     ...           Mac Desktop
# 5            en             other     ...           Mac Desktop
# 6            en             other     ...           Mac Desktop
# 7            en            direct     ...           Mac Desktop
# 8            en             other     ...           Mac Desktop
# 9            en             other     ...           Mac Desktop
# 10           en             other     ...           Mac Desktop
# 11           en             other     ...                iPhone
# 12           en            direct     ...         Other/Unknown
# 13           en             other     ...           Mac Desktop
# 14           en             other     ...                iPhone
# 15           en            direct     ...       Windows Desktop
# 16           en             other     ...         Other/Unknown
# 17           en             other     ...         Other/Unknown
# 18           en               seo     ...         Other/Unknown
# 19           en            direct     ...           Mac Desktop
# 20           en            direct     ...         Other/Unknown
# 21           en            direct     ...           Mac Desktop
# 22           en               seo     ...                iPhone
# 23           en             other     ...           Mac Desktop
# 24           en               seo     ...           Mac Desktop
# 25           en             other     ...           Mac Desktop
# 26           en             other     ...         Other/Unknown
# 27           en             other     ...       Desktop (Other)
# 28           en            direct     ...         Other/Unknown
# 29           en            direct     ...        Android Tablet
# ...         ...               ...     ...                   ...
# 213421       en            direct     ...           Mac Desktop
# 213422       en            direct     ...       Windows Desktop
# 213423       en            direct     ...                iPhone
# 213424       en            direct     ...       Windows Desktop
# 213425       en            direct     ...       Windows Desktop
# 213426       en            direct     ...         Android Phone
# 213427       en            direct     ...       Desktop (Other)
# 213428       en            direct     ...         Android Phone
# 213429       en            direct     ...                iPhone
# 213430       en            direct     ...           Mac Desktop
# 213431       en            direct     ...       Windows Desktop
# 213432       en            direct     ...           Mac Desktop
# 213433       en         sem-brand     ...                  iPad
# 213434       en               seo     ...           Mac Desktop
# 213435       en               seo     ...       Windows Desktop
# 213436       en            direct     ...                iPhone
# 213437       en            direct     ...        Android Tablet
# 213438       en            direct     ...                iPhone
# 213439       en            direct     ...       Windows Desktop
# 213440       en            direct     ...                iPhone
# 213441       en            direct     ...           Mac Desktop
# 213442       en         sem-brand     ...           Mac Desktop
# 213443       en         sem-brand     ...           Mac Desktop
# 213444       en            direct     ...       Windows Desktop
# 213445       en         sem-brand     ...       Windows Desktop
# 213446       en         sem-brand     ...           Mac Desktop
# 213447       en            direct     ...       Windows Desktop
# 213448       en            direct     ...           Mac Desktop
# 213449       en             other     ...                iPhone
# 213450       en            direct     ...                iPhone
#
#         first_browser country_destination signup_delta number_visits  \
# 0              Chrome                 NDF          NaT           NaN
# 1              Chrome                 NDF          NaT           NaN
# 2                  IE                  US      57 days           NaN
# 3             Firefox               other    -278 days           NaN
# 4              Chrome                  US     208 days           NaN
# 5              Chrome                  US      -1 days           NaN
# 6              Safari                  US      -3 days           NaN
# 7              Safari                  US     -10 days           NaN
# 8              Safari                  US    -206 days           NaN
# 9             Firefox                  US       0 days           NaN
# 10            Firefox                  US      -2 days           NaN
# 11          -unknown-                 NDF          NaT           NaN
# 12          -unknown-                  FR     -13 days           NaN
# 13            Firefox                 NDF          NaT           NaN
# 14      Mobile Safari                 NDF          NaT           NaN
# 15             Chrome                  CA      -1 days           NaN
# 16          -unknown-                 NDF          NaT           NaN
# 17          -unknown-                  US      -2 days           NaN
# 18          -unknown-                 NDF          NaT           NaN
# 19             Chrome                  FR       0 days           NaN
# 20          -unknown-                  US      -8 days           NaN
# 21             Chrome                  US      -1 days           NaN
# 22          -unknown-                  US       0 days           NaN
# 23             Safari                 NDF          NaT           NaN
# 24            Firefox                 NDF          NaT           NaN
# 25             Chrome                  FR      -3 days           NaN
# 26          -unknown-                 NDF          NaT           NaN
# 27             Chrome                  US     -10 days           NaN
# 28          -unknown-                  FR       0 days           NaN
# 29          -unknown-                  US      -6 days           NaN
# ...               ...                 ...          ...           ...
# 213421        Firefox                 NDF          NaT          24.0
# 213422             IE                 NDF          NaT          79.0
# 213423      -unknown-                 NDF          NaT          26.0
# 213424         Chrome                 NDF          NaT          14.0
# 213425         Chrome                 NDF          NaT          25.0
# 213426  Chrome Mobile                 NDF          NaT          35.0
# 213427         Chrome                 NDF          NaT         263.0
# 213428      -unknown-                 NDF          NaT         164.0
# 213429      -unknown-                 NDF          NaT          38.0
# 213430         Chrome                 NDF          NaT         273.0
# 213431        Firefox                 NDF          NaT          64.0
# 213432         Safari                 NDF          NaT          10.0
# 213433  Mobile Safari                 NDF          NaT         246.0
# 213434         Chrome                 NDF          NaT          49.0
# 213435         Chrome                 NDF          NaT           7.0
# 213436      -unknown-                 NDF          NaT          25.0
# 213437      -unknown-                 NDF          NaT          62.0
# 213438      -unknown-                 NDF          NaT         105.0
# 213439        Firefox                  US    -259 days           6.0
# 213440  Mobile Safari                 NDF          NaT          59.0
# 213441         Chrome                  ES     -44 days          32.0
# 213442         Chrome                 NDF          NaT         107.0
# 213443         Safari                  US     -13 days         133.0
# 213444         Chrome                 NDF          NaT          15.0
# 213445             IE                  US      -2 days         104.0
# 213446         Safari                 NDF          NaT         110.0
# 213447         Chrome                 NDF          NaT         238.0
# 213448        Firefox                 NDF          NaT          18.0
# 213449  Mobile Safari                 NDF          NaT          75.0
# 213450      -unknown-                 NDF          NaT          41.0
#
#        number_devices  longest_session  total_time_on_site  \
# 0                 NaN              NaN                 NaN
# 1                 NaN              NaN                 NaN
# 2                 NaN              NaN                 NaN
# 3                 NaN              NaN                 NaN
# 4                 NaN              NaN                 NaN
# 5                 NaN              NaN                 NaN
# 6                 NaN              NaN                 NaN
# 7                 NaN              NaN                 NaN
# 8                 NaN              NaN                 NaN
# 9                 NaN              NaN                 NaN
# 10                NaN              NaN                 NaN
# 11                NaN              NaN                 NaN
# 12                NaN              NaN                 NaN
# 13                NaN              NaN                 NaN
# 14                NaN              NaN                 NaN
# 15                NaN              NaN                 NaN
# 16                NaN              NaN                 NaN
# 17                NaN              NaN                 NaN
# 18                NaN              NaN                 NaN
# 19                NaN              NaN                 NaN
# 20                NaN              NaN                 NaN
# 21                NaN              NaN                 NaN
# 22                NaN              NaN                 NaN
# 23                NaN              NaN                 NaN
# 24                NaN              NaN                 NaN
# 25                NaN              NaN                 NaN
# 26                NaN              NaN                 NaN
# 27                NaN              NaN                 NaN
# 28                NaN              NaN                 NaN
# 29                NaN              NaN                 NaN
# ...               ...              ...                 ...
# 213421            1.0        1574097.0           2636982.0
# 213422            1.0         293743.0           1132520.0
# 213423            2.0          51555.0            203195.0
# 213424            1.0         173519.0            198490.0
# 213425            1.0          32496.0            145780.0
# 213426            2.0         272010.0            956095.0
# 213427            4.0         418667.0           3323502.0
# 213428            1.0         814372.0           1458147.0
# 213429            1.0          45444.0            244947.0
# 213430            1.0         421459.0           1826460.0
# 213431            1.0         159190.0            863950.0
# 213432            1.0          85110.0            107982.0
# 213433            1.0         583032.0           2738990.0
# 213434            2.0         254565.0            875540.0
# 213435            1.0          81315.0             84119.0
# 213436            1.0          64276.0            276109.0
# 213437            1.0         159095.0            938932.0
# 213438            1.0        1761855.0           2487549.0
# 213439            1.0         127375.0            169959.0
# 213440            1.0         104493.0            497841.0
# 213441            2.0         361277.0            526082.0
# 213442            1.0         526492.0           2548293.0
# 213443            1.0        1372002.0           5103822.0
# 213444            1.0         214903.0            315712.0
# 213445            1.0         443844.0           1459801.0
# 213446            2.0        1445590.0           5141396.0
# 213447            3.0         748658.0           2878924.0
# 213448            1.0         149128.0            342982.0
# 213449            1.0          66636.0            341609.0
# 213450            1.0        1679278.0           2759210.0
#
#                   action_detail  first_hour
# 0                           NaN           4
# 1                           NaN          17
# 2                           NaN          23
# 3                           NaN           6
# 4                           NaN           6
# 5                           NaN          21
# 6                           NaN           1
# 7                           NaN          19
# 8                           NaN           0
# 9                           NaN           2
# 10                          NaN          19
# 11                          NaN           5
# 12                          NaN           6
# 13                          NaN           8
# 14                          NaN           5
# 15                          NaN          20
# 16                          NaN          21
# 17                          NaN          22
# 18                          NaN           1
# 19                          NaN           1
# 20                          NaN          15
# 21                          NaN          22
# 22                          NaN           3
# 23                          NaN          22
# 24                          NaN          23
# 25                          NaN          13
# 26                          NaN          15
# 27                          NaN          20
# 28                          NaN           4
# 29                          NaN           6
# ...                         ...         ...
# 213421                       p3          23
# 213422      view_search_results          23
# 213423                -unknown-          23
# 213424                       p4          23
# 213425               login_page          23
# 213426      view_search_results          23
# 213427                -unknown-          23
# 213428           user_wishlists          23
# 213429                       p3          23
# 213430      view_search_results          23
# 213431      view_search_results          23
# 213432  wishlist_content_update          23
# 213433           message_thread          23
# 213434                 wishlist          23
# 213435             contact_host          23
# 213436            notifications          23
# 213437            user_listings          23
# 213438      view_search_results          23
# 213439                       p4          23
# 213440                       p3          23
# 213441      view_search_results          23
# 213442  wishlist_content_update          23
# 213443      view_search_results          23
# 213444           update_listing          23
# 213445      view_search_results          23
# 213446             edit_profile          23
# 213447  wishlist_content_update          23
# 213448                       p3          23
# 213449      view_search_results          23
# 213450      view_search_results          23
#
# [213451 rows x 23 columns]

# %%
# Making dataframes to be joined back into data
x = sessions.groupby(['user_id'],as_index=False)  # groups by username

# Total number of actions per user
count_df = x.count() # df of count per use of each parameter type
user_num_visits = count_df[['user_id', 'device_type']]  # Creating a df with username and max number of visits - used device type because that's always max value

# Number of different devices used to access per user
y = sessions.groupby('user_id')['device_type'].nunique()  # Df where sessions is grouped by user, and unique number of devices used is returned
y = y.to_frame()  # Converts pandas series to df
y['user_id']= y.index   # Changes user_id from index to column
y.index = list(range(0,len(y))) # sets index as numeric


# Longest Action by a user
max_time = sessions.groupby('user_id')['secs_elapsed'].max()  # Df where sessions is grouped by user, and unique number of devices used is returned
max_time = max_time.to_frame()  # Converts pandas series to df
max_time['user_id']= max_time.index   # Changes user_id from index to column
max_time.index = list(range(0,len(max_time))) # sets index as numeric

# Total time spent on site per user
total_time = sessions.groupby('user_id')['secs_elapsed'].sum()  # Df where sessions is grouped by user, and unique number of devices used is returned
total_time = total_time.to_frame()  # Converts pandas series to df
total_time['user_id']= total_time.index   # Changes user_id from index to column
total_time.index = list(range(0,len(total_time))) # sets index as numeric

# %%
# The last action a user made 
last_action = sessions.groupby('user_id')['action_detail'].last()
last_action = last_action.to_frame() 
last_action['user_id'] = last_action.index
last_action.index = list(range(0,len(last_action)))

# %%
# The longest action of a user <-- Could Use some help with this one

# longest_action = sessions[['user_id','action_detail','secs_elapsed']].groupby(['user_id','action_detail']).max()

# %%
# Converting Date Columns to Data Time [TRAIN]
users_train_raw['date_account_created'] = pd.to_datetime(users_train_raw['date_account_created'])
users_train_raw['date_first_booking'] = pd.to_datetime(users_train_raw['date_first_booking'])

# Creating Parameter for the Delta between first [TRAIN]
users_train_raw['signup_delta'] = users_train_raw['date_account_created'] - users_train_raw['date_first_booking']

# Converting Date Columns to Data Time [TEST]
test['date_account_created'] = pd.to_datetime(test['date_account_created'])
test['date_first_booking'] = pd.to_datetime(test['date_first_booking'])

# Creating Parameter for the Delta between first [TEST]
test['signup_delta'] = test['date_account_created'] - test['date_first_booking']

# %%
# Add the new parameters into Train
new_train_raw = pd.merge(users_train_raw, user_num_visits, on='user_id', how='left')
new_train_raw = pd.merge(new_train_raw, y, on='user_id', how='left')
new_train_raw = pd.merge(new_train_raw, max_time, on='user_id', how='left')
new_train_raw = pd.merge(new_train_raw, total_time, on='user_id', how='left')
new_train_raw = pd.merge(new_train_raw, last_action, on='user_id', how='left')

# Changing column names in Train
new_train_raw.rename(columns={'device_type_x': 'number_visits','device_type_y': 'number_devices', 'secs_elapsed_x': 'longest_session', 'secs_elapsed_y': 'total_time_on_site' }, inplace=True)


# Add the new parameters to Test
test_w_sessions = pd.merge(test, user_num_visits, on='user_id', how='left')
test_w_sessions = pd.merge(test_w_sessions, y, on='user_id', how='left')
test_w_sessions = pd.merge(test_w_sessions, max_time, on='user_id', how='left')
test_w_sessions = pd.merge(test_w_sessions, total_time, on='user_id', how='left')
test_w_sessions = pd.merge(test_w_sessions, last_action, on='user_id', how='left')

# Changing column names in Test
test_w_sessions.rename(columns={'device_type_x': 'number_visits','device_type_y': 'number_devices', 'secs_elapsed_x': 'longest_session', 'secs_elapsed_y': 'total_time_on_site' }, inplace=True)

# %%
# Extracting the Hour the user first accessed Airbnb
def first_hour_(x):
    return int(str(x)[8:10])

new_train_raw['first_hour'] = new_train_raw.timestamp_first_active.apply(first_hour_)
test_w_sessions['first_hour'] = test.timestamp_first_active.apply(first_hour_)

# %%
# Export to CSV
new_train_raw.to_csv('train_w_sessions.csv',sep=',')
test_w_sessions.to_csv('test_w_sessions.csv',sep=',')

# %% [markdown]
# ## Work bellow builds on above, but adds in the trimming related to addressing NDF, first booking date, and the introduction of session data

# %%
modern_train = new_train_raw.copy()
modern_test = test_w_sessions.copy()

modern_train = modern_train[pd.isnull(modern_train.number_visits) !=  True] # REmoving all rows that predated sessions information
modern_train = modern_train.drop('date_first_booking', 1)  #Removing date of first booking
modern_train = modern_train.drop('signup_delta', 1)   # Removing Delta between signup and booking
modern_train.reset_index(drop=True, inplace=True) 

print len(new_train_raw)
print len(modern_train)


modern_test = modern_test.drop('date_first_booking', 1)
modern_test = modern_test.drop('signup_delta', 1)
# Out:
# 213451
# 73815

# %%
# Export to CSV
modern_train.to_csv('modern_train.csv',sep=',')
modern_test.to_csv('modern_test.csv',sep=',')

# %%
modern_test
# Out:
#           user_id date_account_created  timestamp_first_active     gender  \
# 0      5uwns89zht           2014-07-01          20140701000006     FEMALE
# 1      jtl0dijy2j           2014-07-01          20140701000051  -unknown-
# 2      xx0ulgorjt           2014-07-01          20140701000148  -unknown-
# 3      6c6puo6ix0           2014-07-01          20140701000215  -unknown-
# 4      czqhjk3yfe           2014-07-01          20140701000305  -unknown-
# 5      szx28ujmhf           2014-07-01          20140701000336     FEMALE
# 6      guenkfjcbq           2014-07-01          20140701000514       MALE
# 7      tkpq0mlugk           2014-07-01          20140701000649  -unknown-
# 8      3xtgd5p9dn           2014-07-01          20140701000837  -unknown-
# 9      md9aj22l5a           2014-07-01          20140701002245  -unknown-
# 10     gg3eswjxdf           2014-07-01          20140701002406  -unknown-
# 11     fyomoivygn           2014-07-01          20140701002531     FEMALE
# 12     iq4kkd5oan           2014-07-01          20140701002539       MALE
# 13     6k1xls6x5j           2014-07-01          20140701002912  -unknown-
# 14     jodmb2ok1f           2014-07-01          20140701003057  -unknown-
# 15     eq6fy0m4vc           2014-07-01          20140701003103     FEMALE
# 16     yq4i7nfh6l           2014-07-01          20140701003421  -unknown-
# 17     q5pibqdous           2014-07-01          20140701003533  -unknown-
# 18     i0sc6d3j8s           2014-07-01          20140701003723     FEMALE
# 19     br5mcrsqzn           2014-07-01          20140701004052       MALE
# 20     rddbczuxx1           2014-07-01          20140701004053     FEMALE
# 21     glck7hlmzz           2014-07-01          20140701004259  -unknown-
# 22     sxpkaxep8n           2014-07-01          20140701004343       MALE
# 23     sr4ntmalz2           2014-07-01          20140701004344  -unknown-
# 24     f6wueq1ccn           2014-07-01          20140701004359  -unknown-
# 25     ovc6nwn6mj           2014-07-01          20140701004654       MALE
# 26     n10skstp90           2014-07-01          20140701004748     FEMALE
# 27     5jrbdigmv4           2014-07-01          20140701004809  -unknown-
# 28     d45nngmojp           2014-07-01          20140701004817  -unknown-
# 29     y0frb6t1kq           2014-07-01          20140701005250  -unknown-
# ...           ...                  ...                     ...        ...
# 62066  bsv2ev628t           2014-09-30          20140930231454  -unknown-
# 62067  06echc56pl           2014-09-30          20140930231518     FEMALE
# 62068  niqgaye2ov           2014-09-30          20140930231952  -unknown-
# 62069  61iwzuhw6e           2014-09-30          20140930232126     FEMALE
# 62070  gks02el96u           2014-09-30          20140930232237     FEMALE
# 62071  v4r1161l0r           2014-09-30          20140930232253  -unknown-
# 62072  p1clbqd0o6           2014-09-30          20140930232331  -unknown-
# 62073  ozb2z0km6l           2014-09-30          20140930232507  -unknown-
# 62074  w3e3sp6i70           2014-09-30          20140930232551  -unknown-
# 62075  q5bxbq0asg           2014-09-30          20140930232613     FEMALE
# 62076  1xa5t3t0la           2014-09-30          20140930233113       MALE
# 62077  zuvz7gfpjz           2014-09-30          20140930233305  -unknown-
# 62078  gpusl6ppgf           2014-09-30          20140930233535  -unknown-
# 62079  gpijioh4eh           2014-09-30          20140930233902       MALE
# 62080  3ptlvdxss9           2014-09-30          20140930234128  -unknown-
# 62081  f9a1ncjnrg           2014-09-30          20140930234425     FEMALE
# 62082  kofaz2kh70           2014-09-30          20140930234515  -unknown-
# 62083  6xrmom7hjo           2014-09-30          20140930234551       MALE
# 62084  cg9wqgnad2           2014-09-30          20140930234612       MALE
# 62085  jg618z94wo           2014-09-30          20140930234617     FEMALE
# 62086  u7lv3glv6y           2014-09-30          20140930234703  -unknown-
# 62087  o6ofmozucx           2014-09-30          20140930234751       MALE
# 62088  wcw7xggeqp           2014-09-30          20140930234904  -unknown-
# 62089  m22pw2pkxr           2014-09-30          20140930235000       MALE
# 62090  8yvhec201j           2014-09-30          20140930235019  -unknown-
# 62091  cv0na2lf5a           2014-09-30          20140930235232  -unknown-
# 62092  zp8xfonng8           2014-09-30          20140930235306  -unknown-
# 62093  fa6260ziny           2014-09-30          20140930235408  -unknown-
# 62094  87k0fy4ugm           2014-09-30          20140930235430  -unknown-
# 62095  9uqfg8txu3           2014-09-30          20140930235901     FEMALE
#
#         age signup_method  signup_flow language affiliate_channel  \
# 0      35.0      facebook            0       en            direct
# 1       NaN         basic            0       en            direct
# 2       NaN         basic            0       en            direct
# 3       NaN         basic            0       en            direct
# 4       NaN         basic            0       en            direct
# 5      28.0         basic            0       en         sem-brand
# 6      48.0         basic           25       en            direct
# 7       NaN         basic            0       en            direct
# 8       NaN         basic            0       en            direct
# 9       NaN         basic            0       en     sem-non-brand
# 10      NaN         basic            0       en            direct
# 11     30.0         basic           25       en            direct
# 12     24.0      facebook            0       en            direct
# 13      NaN         basic            0       en            direct
# 14      NaN         basic            0       en            direct
# 15     56.0         basic            0       en            direct
# 16      NaN         basic            0       en            direct
# 17     30.0         basic            0       en            direct
# 18     33.0         basic            0       en            direct
# 19     31.0      facebook            0       en               seo
# 20     53.0         basic            0       en         sem-brand
# 21      NaN         basic            0       en            direct
# 22     35.0      facebook            0       en               seo
# 23      NaN         basic            0       en            direct
# 24      NaN         basic            0       en     sem-non-brand
# 25     34.0         basic            0       en            direct
# 26     25.0         basic            0       en         sem-brand
# 27      NaN         basic            0       en         sem-brand
# 28     27.0         basic            0       en            direct
# 29      NaN         basic            0       en         sem-brand
# ...     ...           ...          ...      ...               ...
# 62066   NaN        google           12       en            direct
# 62067  48.0         basic            0       en            direct
# 62068   NaN         basic            0       en               seo
# 62069  24.0      facebook           25       en            direct
# 62070  32.0      facebook            0       en               seo
# 62071   NaN         basic            0       en            direct
# 62072   NaN         basic           23       en            direct
# 62073   NaN         basic           23       en            direct
# 62074   NaN         basic            0       en            direct
# 62075  40.0      facebook            0       en         sem-brand
# 62076  39.0      facebook            0       en               seo
# 62077   NaN         basic            0       en               seo
# 62078   NaN         basic            0       en               seo
# 62079  44.0         basic            0       en               seo
# 62080  39.0         basic            0       en               seo
# 62081  34.0      facebook           23       en            direct
# 62082   NaN         basic            0       en               seo
# 62083  40.0      facebook           23       en            direct
# 62084  27.0      facebook            0       en            direct
# 62085  24.0      facebook            0       en            direct
# 62086   NaN         basic           25       en            direct
# 62087  55.0         basic            0       en         sem-brand
# 62088  34.0         basic            0       en            direct
# 62089  32.0         basic            0       en            direct
# 62090   NaN         basic            0       en               seo
# 62091  31.0         basic            0       en            direct
# 62092   NaN         basic           23       ko            direct
# 62093   NaN         basic            0       de            direct
# 62094   NaN         basic            0       en         sem-brand
# 62095  49.0         basic            0       en             other
#
#       affiliate_provider first_affiliate_tracked signup_app first_device_type  \
# 0                 direct               untracked      Moweb            iPhone
# 1                 direct               untracked      Moweb            iPhone
# 2                 direct                  linked        Web   Windows Desktop
# 3                 direct                  linked        Web   Windows Desktop
# 4                 direct               untracked        Web       Mac Desktop
# 5                 google                     omg        Web   Windows Desktop
# 6                 direct               untracked        iOS            iPhone
# 7                 direct               untracked        Web       Mac Desktop
# 8                 direct               untracked        Web       Mac Desktop
# 9                 google                     omg        Web   Windows Desktop
# 10                direct               untracked        Web   Windows Desktop
# 11                direct               untracked        iOS            iPhone
# 12                direct                  linked        Web       Mac Desktop
# 13                direct                  linked        Web       Mac Desktop
# 14                direct               untracked      Moweb              iPad
# 15                direct                  linked        Web   Windows Desktop
# 16                direct               untracked        Web            iPhone
# 17                direct                  linked        Web   Windows Desktop
# 18                direct                     omg        Web    Android Tablet
# 19                google                  linked        Web   Windows Desktop
# 20                google                  linked        Web       Mac Desktop
# 21                direct               untracked        Web       Mac Desktop
# 22                google                  linked        Web   Windows Desktop
# 23                direct               untracked        Web       Mac Desktop
# 24                google                     omg        Web   Windows Desktop
# 25                direct                  linked      Moweb            iPhone
# 26                google                     omg        Web       Mac Desktop
# 27                  bing                     omg        Web   Windows Desktop
# 28                direct                 product        Web       Mac Desktop
# 29                google                  linked        Web              iPad
# ...                  ...                     ...        ...               ...
# 62066             direct               untracked    Android     Android Phone
# 62067             direct               untracked        Web       Mac Desktop
# 62068             google               untracked        Web       Mac Desktop
# 62069             direct               untracked        iOS            iPhone
# 62070           facebook               untracked        Web              iPad
# 62071             direct               untracked      Moweb     Android Phone
# 62072             direct               untracked    Android     Android Phone
# 62073             direct               untracked    Android     Android Phone
# 62074             direct                  linked      Moweb            iPhone
# 62075             google                     omg        Web   Windows Desktop
# 62076           facebook               untracked        Web            iPhone
# 62077             google               untracked        Web       Mac Desktop
# 62078             google               untracked        Web              iPad
# 62079             google                  linked        Web       Mac Desktop
# 62080             google                  linked        Web   Windows Desktop
# 62081             direct               untracked    Android     Android Phone
# 62082             google               untracked        Web       Mac Desktop
# 62083             direct               untracked    Android     Android Phone
# 62084             direct               untracked        Web       Mac Desktop
# 62085             direct                  linked        Web            iPhone
# 62086             direct               untracked        iOS            iPhone
# 62087             google                     omg        Web   Windows Desktop
# 62088             direct               untracked        Web       Mac Desktop
# 62089             direct                  linked        Web   Windows Desktop
# 62090              yahoo                  linked        Web   Windows Desktop
# 62091             direct               untracked        Web   Windows Desktop
# 62092             direct               untracked    Android     Android Phone
# 62093             direct                  linked        Web   Windows Desktop
# 62094             google                     omg        Web       Mac Desktop
# 62095              other           tracked-other        Web   Windows Desktop
#
#        first_browser  number_visits  number_devices  longest_session  \
# 0      Mobile Safari            8.0             2.0          64883.0
# 1      Mobile Safari           19.0             2.0          61881.0
# 2             Chrome           58.0             1.0         270618.0
# 3                 IE           11.0             1.0         106481.0
# 4             Safari           19.0             1.0         219369.0
# 5             Chrome            8.0             1.0          54263.0
# 6          -unknown-           30.0             1.0         298327.0
# 7             Chrome           33.0             1.0         246526.0
# 8             Chrome          283.0             4.0        1270755.0
# 9            Firefox          115.0             2.0        1598749.0
# 10           Firefox            3.0             1.0           1172.0
# 11         -unknown-           29.0             1.0          38480.0
# 12            Safari            3.0             1.0            696.0
# 13            Chrome            2.0             1.0            401.0
# 14     Mobile Safari           50.0             2.0         495530.0
# 15            Chrome          213.0             2.0         970934.0
# 16     Mobile Safari            1.0             1.0              NaN
# 17            Chrome           56.0             2.0         237714.0
# 18                IE           37.0             1.0         197291.0
# 19            Chrome           51.0             1.0         176550.0
# 20            Safari           16.0             1.0         145327.0
# 21           Firefox           70.0             1.0         114195.0
# 22            Chrome           17.0             2.0         988911.0
# 23           Firefox           55.0             1.0          43872.0
# 24            Chrome            7.0             1.0          10681.0
# 25     Mobile Safari          824.0             2.0         237013.0
# 26            Chrome          119.0             2.0         891311.0
# 27                IE           28.0             2.0         120219.0
# 28            Chrome           65.0             1.0         528822.0
# 29     Mobile Safari          333.0             5.0        1142277.0
# ...              ...            ...             ...              ...
# 62066      -unknown-           92.0             1.0        1505844.0
# 62067         Safari          139.0             1.0         537852.0
# 62068        Firefox           18.0             1.0          64191.0
# 62069      -unknown-           79.0             1.0         474761.0
# 62070  Mobile Safari            1.0             1.0              NaN
# 62071  Chrome Mobile           17.0             1.0          21770.0
# 62072      -unknown-           52.0             1.0         177913.0
# 62073      -unknown-          187.0             1.0         116408.0
# 62074  Mobile Safari           38.0             1.0         237210.0
# 62075        Firefox           33.0             2.0        1786576.0
# 62076  Mobile Safari           13.0             1.0          65424.0
# 62077        Firefox           28.0             1.0         510146.0
# 62078  Mobile Safari           25.0             1.0         295270.0
# 62079         Chrome          201.0             2.0        1420096.0
# 62080        Firefox           72.0             1.0         277652.0
# 62081      -unknown-           77.0             1.0         351779.0
# 62082         Safari            8.0             1.0         287057.0
# 62083      -unknown-           24.0             1.0          26695.0
# 62084        Firefox           56.0             1.0         225427.0
# 62085  Mobile Safari           31.0             2.0         240463.0
# 62086      -unknown-           93.0             1.0         114644.0
# 62087        Firefox           30.0             2.0         113302.0
# 62088         Chrome           50.0             1.0         147175.0
# 62089         Chrome           38.0             1.0         278000.0
# 62090         Chrome           47.0             1.0         186065.0
# 62091             IE           93.0             2.0        1551558.0
# 62092      -unknown-           20.0             1.0          14307.0
# 62093        Firefox           78.0             1.0         204591.0
# 62094         Safari           15.0             2.0         253296.0
# 62095         Chrome           16.0             2.0        1752436.0
#
#        total_time_on_site                action_detail  first_hour
# 0                119187.0          view_search_results           0
# 1                250119.0               header_userpic           0
# 2                975575.0          view_search_results           0
# 3                123001.0      wishlist_content_update           0
# 4                454023.0        message_to_host_focus           0
# 5                 60924.0                    dashboard           0
# 6                640922.0                           p3           0
# 7                391231.0  change_trip_characteristics           0
# 8               8481847.0      wishlist_content_update           0
# 9               5084265.0                           p3           0
# 10                 1573.0               header_userpic           0
# 11               157911.0              listing_reviews           0
# 12                  917.0                        login           0
# 13                  401.0               header_userpic           0
# 14              1072131.0                  create_user           0
# 15              5167443.0      wishlist_content_update           0
# 16                    NaN               oauth_response           0
# 17               630983.0                    -unknown-           0
# 18              1117751.0      wishlist_content_update           0
# 19               364258.0      wishlist_content_update           0
# 20               365348.0               header_userpic           0
# 21               662916.0          view_search_results           0
# 22              1194422.0                    -unknown-           0
# 23               493238.0                  create_user           0
# 24                14101.0               oauth_response           0
# 25              8544164.0                 user_profile           0
# 26              2699541.0                  create_user           0
# 27               480773.0      wishlist_content_update           0
# 28              1422903.0                    -unknown-           0
# 29              6242523.0  change_trip_characteristics           0
# ...                   ...                          ...         ...
# 62066           1828319.0                           p3          23
# 62067           2891734.0      wishlist_content_update          23
# 62068            213069.0                  create_user          23
# 62069           1235413.0              listing_reviews          23
# 62070                 NaN                        login          23
# 62071            134755.0          view_search_results          23
# 62072            315957.0               user_wishlists          23
# 62073            751283.0          view_search_results          23
# 62074            676565.0          view_search_results          23
# 62075           2748721.0          view_search_results          23
# 62076            277706.0                    -unknown-          23
# 62077            938847.0                   your_trips          23
# 62078            715253.0                           p3          23
# 62079           6288548.0                    -unknown-          23
# 62080           1052227.0  change_trip_characteristics          23
# 62081            980574.0                 user_profile          23
# 62082            526862.0                  create_user          23
# 62083             86052.0                    -unknown-          23
# 62084            882738.0          view_search_results          23
# 62085            575391.0          view_search_results          23
# 62086           1167663.0          view_search_results          23
# 62087            634893.0               header_userpic          23
# 62088            398555.0               update_listing          23
# 62089            464202.0          view_search_results          23
# 62090            572202.0          view_search_results          23
# 62091           2534232.0               manage_listing          23
# 62092             51618.0                notifications          23
# 62093            823297.0      wishlist_content_update          23
# 62094            352068.0                    dashboard          23
# 62095           2804544.0  user_profile_content_update          23
#
# [62096 rows x 20 columns]
